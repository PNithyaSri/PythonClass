# %%
import random

# %%
ladder = {1:38, 4:14, 8:30, 21:42, 28:76, 50:67, 71:92, 80:99}
snake = {32:10, 36:6, 48:26, 62:18, 88:24, 95:56, 97:78}
def turn(pos):
      if pos in ladder:
        print("Ladder")
        pos = ladder[pos]
        return pos
      else:
        return pos+dice

      if pos in snake:
        print("Snake")
        pos = snake[pos]
        return pos
      else:
        return pos+dice
player1 = 0
player2 = 0
while _:
  move = input("Player1 throw the dice ")
  if move == 'end':
    break
  else:
    dice = random.randrange(1,7)
    print(dice)
    player1 = turn(player1)
    print("Player1 is at {}".format(player1))
  if player1 >= 100:
    print("Player1 is winner")
    break
  move = input("Player2 throw the dice ")
  if move == 'end':
    break
  else:
    dice = random.randrange(1,7)
    print(dice)
    player2 = turn(player2)
    print("Player2 is at {}".format(player2))

  if player2 >= 100:
    print("Player2 is winner")
    break
# Out:
# Player1 throw the dice d
# 1
# Player1 is at 1
# Player2 throw the dice d
# 5
# Player2 is at 5
# Player1 throw the dice d
# 5
# Ladder
# Player1 is at 38
# Player2 throw the dice d
# 2
# Player2 is at 7
# Player1 throw the dice d
# 6
# Player1 is at 44
# Player2 throw the dice d
# 6
# Player2 is at 13
# Player1 throw the dice d
# 2
# Player1 is at 46
# Player2 throw the dice d
# 6
# Player2 is at 19
# Player1 throw the dice d
# 6
# Player1 is at 52
# Player2 throw the dice d
# 4
# Player2 is at 23
# Player1 throw the dice d
# 2
# Player1 is at 54
# Player2 throw the dice d
# 6
# Player2 is at 29
# Player1 throw the dice d
# 1
# Player1 is at 55
# Player2 throw the dice d
# 5
# Player2 is at 34
# Player1 throw the dice d
# 5
# Player1 is at 60
# Player2 throw the dice d
# 5
# Player2 is at 39
# Player1 throw the dice d
# 5
# Player1 is at 65
# Player2 throw the dice d
# 6
# Player2 is at 45
# Player1 throw the dice d
# 1
# Player1 is at 66
# Player2 throw the dice d
# 1
# ...
